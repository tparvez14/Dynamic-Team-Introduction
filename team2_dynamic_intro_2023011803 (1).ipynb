# %% [markdown]
# <h1>Dynamic Introduction</h1>
# <h2>Team 2</h2>
# <hr>
# <br>
# <ol></ol>
# <li>Htet Aung Kyaw</li>
# <li>Kevin Kabore</li>
# <li>Lynda Villarreal</li>
# <li>Tangina Parvez</li>
# <li>Udhayaa Tamilvanan</li>
# <br>
#
# We are <strong><i>Team 2</i></strong>, a team of committed and enthusiastic people from various backgrounds and skill sets. We decided to keep the team introduction exciting and change the user's experience every time they play. We have a few multiple-choice questions to guess about your classmates, and you will encounter many fun moments. It helps to know about each of our team members in a better way.
#
# Meet, <strong>Htet</strong>, <u>a heavy potato chips consumer</u> who loves working on UX design and has more than five years of experience in international business. He is interested in sports, especially Swimming, and enjoys board games. He belongs to a beautiful country that used called <u>Burma</u>. Next comes <strong>Tangina</strong>, who is from <u>the country of rivers</u> and is <u>an animal lover</u>. Experienced customer success director focused on business development who likes to travel and explore new places, and reading is her favorite thing to do. Our super-talented <strong>Udhayaa</strong> is from <u>the most powerful democratic nation</u>. She is an academic director with more than five years of experience and a keen interest in creating an impact in education, digital transformation, and sustainability. She loves to play strategic board games and enjoys being around friends. Up next is <strong>Lynda</strong>, representing <u>the nation of the Inca Empire</u>. Experienced business analyst within the bank and energy industry, with a strong understanding of consumer insights and market trends. Her passion is dancing. Finally, meet <strong>Kevin</strong>, an Economics graduate and a project manager with a track record of completing projects, who makes up our team. He is full of energy and crazy about soccer and likes to play the game as well. Interestingly he gets to know <u>the history of Napoleon Bonaparte</u> as a birthright.

# %%
######### Modules import #########
# import random function to generate random question for every round
import random

######### Declare variables #########

# team members profile are store in a nested list
team_members=[
    [1, 
     'Htet Aung Kyaw', 
     'Hank',
     'He',
     'His',
     'him',
     'Myanmar(formerly Burma)', 
     'Asia',
     'Burmese, English, Chinese, and a little Spanish',
     'International Economics and Trading', 
     'an International Business Manager and a UX Designer', 
     'Artificial Intelligence (A.I.) and Machine Learning (M.L.)',
     'Swimming, Table Tennis, or Board Games', 
     'California',
     'Heavy potato chips consumer',
     'hkyaw@student.hult.edu',
      3,
     'want to buy a mega fish bowl and raise a shark in it',
     'Monkey D. Luffy (the pirate)',
     'Monhinga',
     'Mohinga is a rice noodle and fish soup from Myanmar \n'
     'and an essential part of Burmese cuisine, considered \n'
     'by many to be the national dish of Myanmar.\n',
     'Greece',
     'Kevin Kabore',
     'Bear'],
    [2, 
     'Kevin Kabore', 
     'Kevin',
     'He',
     'His',
     'him',
     "France/Cote d'Ivoire", 
     'Europe and Africa',
     'French and English',
     'Economics', 
     'a Marketing and Finance Personnel', 
     'Metaverse, Crypto, Tech, Sport',
     'Football (soccer)', 
     'California',
     'Fuun',
     'kkabore@student.hult.edu',
      2,
     'wanted to marry Rihana in younger age. Well still want',
     'Dora the explorer',
     'Attieke',
     'Acheke, also spelled attiéké, "attcheke" or akyeke, \n'
     'is a side dish made from cassava that is popular and \n'
     'traditional in West Africa. The dish is prepared from \n'
     'fermented cassava pulp that has been grated or granulated.\n'
     'Dried attiéké is also prepared, which is similar in '
     'texture to couscous.',
     'Abidjan',
     'Htet Aung Kyaw',
     'Lion'],
    [3, 
     'Lynda Villarreal', 
     'Lyn',
     'She',
     'Her',
     'her',
     'Peru', 
     'South America',
     'Spanish and English',
     'Business Administration', 
     'a Business Analysts', 
     'Consumer, Insights',
     'Dancing', 
     'California',
     "When I'm hungry I get angry",
     'lvillarreal@student.hult.edu',
     4,
     'once I burned the water while boiling it',
     'Alice in Wonderland',
     'Pachamanca',
     "Pachamanca is traditional Peruvian dish that’s \n"
     "cooked underground with the help of hot stones. \n"
     "Red meat, lamb, pork, cuy (Peruvian guinea pig), \n"
     "and chicken are cooked together along with potatoes, \n"
     "sweet potatoes, corn, green lima beans, and yucca.",
     'Jungle',
     'Susy Diaz',
     'Swan'],
    [4, 
     'Tangina Parvez', 
     'Jisha',
     'She',
     'Her',
     'her',
     'Bangladesh ', 
     'Asia',
     'Bangla, English and Hindi',
     'English literature', 
     'Director of customer success', 
     'Marketing Analytics',
     'Reading and Travel', 
     'California',
     'Animal lover',
     'tparvez@student.hult.edu',
     1,
     "don't know how to swim but love jet ski",
     'Donald Duck',
     'Panta Ilish',
     "Panta ilish is a dish from Bangladesh that combines\n"
     "a bowl of panta bhat—cooked and soaked rice—with \n"
     "fried ilish fish.",
     'Sentosa Island',
     'Robert Downey Jr.',
     'Parrot'],
    [5, 
     'Udhayaa Tamilvanan', 
     'Udhayaa',
     'She',
     'Her',
     'her',
     'India ', 
     'Asia',
     'Tamil, English and Hindi',
     'Business Administration', 
     'Director', 
     'Sustainability and Education',
     'Board Games', 
     'California',
     'Lighthearted',
     'utamilvanan@student.hult.edu',
     3,
     'podcast enthusiast',
     'Winnie the Pooh',
     'Biriyani',
     'Biryani is a mixed rice dish originating among the Muslims\n'
     'of the Indian subcontinent. It is made with Indian spices,\n'
     'rice, and usually some type of meat or in some cases without any meat,\n'
     'and sometimes, in addition, eggs and potatoes.',
     'Ladakh',
     'Deepika Padukone',
     'Giraffe']    
]

# This list has been seperated from the main list above because this list is
# added after the debugging of the conditional statements.
# we thought that it would be fun to add in but don't want to mess with the
# original list

# Note: if there there pic with / make sure to add another "/" 
# since the first one would likely to be ignore by python.

# Reference: Picture credited to https://www.asciiart.eu website
# picture list for the team
profile_pic = ["""
    /'~~~~~~~~\|/
  ,/'      ____ `|
  |   ,,__/     '| 
 ,|_./___   ___  |  |
  |-(  .)-(.  )` |,'
 (|  ~~~   ~~~   |)
  |     `-'      |'
   \   ,____,   /
    \   `--'   /
     |\______/|
    |\________/|
    \----------/
    """,
    """
   ,ad8888baaa,_
 a88888888888888a,
I888888888888888P",
I88888PPPP''''add88
I"_,,_   _,,_ `Y888
I .--. , .--.   "8P",
I `--'/  `--'    8),)
I    /          ,8,;)
I    "--'      ,d8|'
Ib,ad8888ba,,ad888I
I88P''''''Y888888P|
`888~~88~~888888P'|
 `Y88888888PP"'   (
   `"Y''''   _.,-"'
     \.,--''
    """,
    """
     ,-.,~~.
   ,'///||\\`.
  ///(((||)))\\.
 (((  ,   ,  )))
 _)))   -    |(_
._//\   -   /\\_.
`-'_/`-._.-'\-`-'
  ' \/=._.=\/ 
    """,
    """
         _,--.,'  `--._
       ,'    ;         `._
      /    ,'`-""-.       y
     y  ,-' ))||\\`.       y
    /   /// // || \\ \      `.
   /   ((( /   ||  \\ \      y
  |    |` ,,a..` `  ,,a\      y
  |    | '-`-'-`   '-`-'\      `|
  y    |        ,        \       )
 /     |       (._.)      y      )
|      |                  |      )
 \     | `---',--.--.`---'|     )`)
  \    \    |  `---'  |   |    (`-'
  ``-.  ".   \  -    /   /     \`-
  `-'    |`---`-----'---(   \ \ `-'
  --'    /              \ \ `-`-'
   `--'-'                `-`-'     
    """,
    """
           __.------._
         .' -|  -   . `.
        / '.' `-. `     \\
       /  /      `.  `   \\
      |  /         `.     |
      |  |           `.   |
      |  |.d88b.  .d88b\  |
      | ||888888=888888=` |
      |  |"888"/ \"888"|| |
      |  |    ((_))    |  |
      | `|`   _. ._   '|  |
      |  |   <--=-->   |  |
      /  /    `---'    |  |
     /   |`.    "    .'/  \\
    / / | | `-.___.-' ||   \\
   /     '|           |  \  \\
  /'  /   |           |\   ` \\
 /   .  /-'           `-..__  \\
/ .-'| ||      l_       |   `-.\\
    """]



# question 2 list for index 1 for question and the other indexes for choices
# this nested is added later for a random a choice of 4 question rather than
# a choice of 5 like we could in the other question.
ques_2 = [[1,"Which country is well known for wearing brass coils around women"
             " necks?\n" 
             "1.Bangladesh\n" 
             "2.India\n" 
             "3.Myanmar\n"
             "4.Peru"],
          [2, "Which country is Napoleon Bonaparte from?\n" 
              "1.Peru\n"
              "2.France\n"
              "3.India\n"
              "4.Myanmar(Burma)"],
          [3, "Which country did Inca Empire originate?\n"
              "1.France\n"
              "2.Bangladesh\n"
              "3.India\n"
              "4.Peru"],
          [4, "Which country has the highest number of rivers in the world?\n"
              "1.Bangladesh\n"
              "2.Myanmar(Burma)\n"
              "3.France\n"
              "4.Peru"],
          [5, "Where is the largest postal network in the world?\n"
              "1.Myanmar(Burma)\n"
              "2.France\n"
              "3.India\n"
              "4.Bangladesh"]]

# list for question 2 places pic
# Picture credited to https://www.asciiart.eu/people
places_pic = ["""
 /////////////\\\\\
(((((((((((((( \\\\\
))) ~~      ~~  (((
((( (*)     (*) )))
)))     <       (((
((( '\______/`  )))
)))\___________/(((
       _) (_
       _) (_
       _) (_
       _) (_
      / \\_/ \\
Myanmar is also called Burma!
""",
"""
         ________
        /        \\
     __/       (o)\\__
    /     ______\\   \\
    |____/__  __\\____|
       [  --~~--  ]
        |(  L   )|
  ___----\\  __  /----___
 /   |  < \\____/ >   |   \\
/    |   < \\--/ >    |    \\
||||||    \\ \\/ /     ||||||
|          \\  /   o       |
|     |     \\/   === |    |
|     |      |o  ||| |    |
|     \______|   +#* |    |
|            |o      |    |
 \\           |      /     /
 |\\__________|o    /     /
 |           |    /     /
""",
"""
                ,'|`.
               (->_<-)
               [ )@( ]
              ,-]_H_[-.
            ,'_ _ _ _ _`.
           |             |
         , |_____________| .
       ,' _ _ _ _ _ _ _ _ _ `.
      |                       |
    ,'|_______________________|`.
  ,'_ _ _ _ _ _ _ _ _ _ _ _ _ _ _`.
 |                                 |
 |_________________________________|
""",
"""
                                        |
                                      \\ _ /
                                    -= (_) =-
   .\/.                               /   \\
.\\\//o\\\                      ,\\/.      |              ,~
//o\\\|,\\/.   ,.,.,   ,\/.  ,\//o\\\                     |\\
  |  |//o\\  /###/#\\  //o\\  /o\\\|                      /| \\
^^|^^|^~|^^^|' '|:|^^^|^^^^^|^^|^^^''''''''("~~~~~~~~/_|__\\~~~~~~~~~~
 .|'' . |  '''""'"''. |`===`|''  '''''''' (" ~~~~ ~ ~======~~  ~~ ~
    ^^   ^^^ ^ ^^^ ^^^^ ^^^ ^^ ^^ '' '''( " ~~~~~~ ~~~~~  ~~~ ~
""",
"""
         | _]
      .--||-----.
      |  ||     |
 _____|__||_____|
           \\ |
 _______    ||
|==   []|   ||
|  ==== |   ||
'-------'   ||
            ||
            ||
            ||
^^^^^^^^^^^^^^^^^^^^
"""]

# this list store for the pic of correct and incorrect graphic
# Picture credited to https://patorjk.com/software/taag/ website
true_false = ["""
         ____________________________________________
________|      __   __   __   __   ___  __  ___      |_______
\\       |     /  ` /  \ |__) |__) |__  /  `  |       |      /
 \\      |     \__, \__/ |  \ |  \ |___ \__,  |       |     /
 /      |____________________________________________|     \\
/__________)                                        (_______\\
""",
"""
  _   _  ____  _____  ______ 
 | \\ | |/ __ \\|  __ \\|  ____|
 |  \\| | |  | | |__) | |__   
 | . ` | |  | |  ___/|  __|  
 | |\\  | |__| | |    | |____ 
 |_| \\_|\\____/|_|    |______|
"""
]


# TEAM 2 characters is created from https://patorjk.com/software/taag/
# credits goes to the creater of the website
# """ triple quote is alittle complicated to keep within the suggested boundary
# so we keep it cross over the 80 characters length border"""

########## Input 1 ##########
# Input for Question 1 which is user's name
user_name = input(prompt=f"""
 .----------------.  .----------------.  .----------------.  .----------------.   .----------------. 
| .--------------. || .--------------. || .--------------. || .--------------. | | .--------------. |
| |  _________   | || |  _________   | || |      __      | || | ____    ____ | | | |    _____     | |
| | |  _   _  |  | || | |_   ___  |  | || |     /  \     | || ||_   \  /   _|| | | |   / ___ `.   | |
| | |_/ | | \_|  | || |   | |_  \_|  | || |    / /\ \    | || |  |   \/   |  | | | |  |_/___) |   | |
| |     | |      | || |   |  _|  _   | || |   / ____ \   | || |  | |\  /| |  | | | |   .'____.'   | |
| |    _| |_     | || |  _| |___/ |  | || | _/ /    \ \_ | || | _| |_\/_| |_ | | | |  / /____     | |
| |   |_____|    | || | |_________|  | || ||____|  |____|| || ||_____||_____|| | | |  |_______|   | |
| |              | || |              | || |              | || |              | | | |              | |
| '--------------' || '--------------' || '--------------' || '--------------' | | '--------------' |
 '----------------'  '----------------'  '----------------'  '----------------'   '----------------' \n
Hello there! Welcome to our playground...\n
If we just tell you our team members profile, it would be boring.
Since we are the fun + "WEIRD" team, how about we introduce ourselves in a weird way...\n
Let's start with your name:\n
<Press Enter to Continue> """)

# page break
print('-' * 100)

# Capitalize the user's name in case user just enter lower case
user_name = user_name.capitalize()


######### Input 2 #########

# Question 2 ask users a unique features about the teammate countries.
# question are randomly generated

# declare a variable to store random generated number
random_ques_2 = random.randint(0,4)

# ask for user input based on a random generated question
ans_2 = input(prompt=f"""
Welcome {user_name}!\n
Let's see if you could got this right...\n
{ques_2[random_ques_2][1]}\n
Choose a number:
<Press Enter to Continue> """)

# page break
print('-' * 100)

######### Result 2 #########

# The correct user will see a picture represent the answer and
# the inccorect ones won't have that chance.

# use if statement to check if the user choose from the given choices
if ans_2 == '1' or ans_2 == '2' or ans_2 == '3' or ans_2 == '4':
    #convert ans_2 string into integer
    ans_2 = int(ans_2)
    # inner statement to check which teammate that the random question belong to
    if ans_2 == team_members[random_ques_2][16]:
        print(f"{places_pic[random_ques_2]}")
        print(f"\nCorrect! Great job {user_name}.\n We are starting to like "
               "you...\n")
    else:
        print(f"\nOops! That's alright.\n We are sure that you will get the "
               "next one right.\n")
        
else:
    print("\nOh! Seems like you got a typo. Let's got you another "
          "one...\n")

# to make answer more prominent from the next question 
print('^' * 100)

######### Input 3 #########

# Question 3 give users a strange characteristic about a person,
# and ask the users to guess which person in the team would it be.
# the character is random choice from the list   

# generate random number for question 3
random_ques_3 = random.randint(0,4)

# 
ans_3 = input(prompt=f"""
Alright! let us tell you a secret. Our team is full of weirdos.\n
Who do you think {team_members[random_ques_3][14]} person is?\n
1.{team_members[0][1]}
2.{team_members[1][1]}
3.{team_members[2][1]}
4.{team_members[3][1]}
5.{team_members[4][1]}\n
Choose a number:
<Press Enter to Continue> """)

# page break
print('-' * 100)

######### Result 3 #########

# We praise the correct user, and mess with the incorrect user.

# use if statement to check if the user choose from the given choices
if ans_3 == '1' or ans_3 == '2' or ans_3 == '3' or ans_3 == '4' or ans_3 == '5':
    
    #convert ans_2 string into integer
    ans_3 = int(ans_3)
    
    # inner statement to check which teammate that the random question belong to
    if ans_3 == team_members[random_ques_3][0]:
        #true_false is to print correct or incorrect banner
        print(f"{true_false[0]}")
        print(f"\nWow! You seems to understand the weirdos {user_name}."
               "\nHope you are not as crazy as we are...\n")
    else:
        #true_false is to print correct or incorrect banner
        print(f"{true_false[1]}")
        print(f"\nWe knew it! You don't seems to understand the weirdos."
               "\nBut don't worry some more crazy questions to go.\n")
else:
    print("\nHaha! Seems like you are looking for some other clown. "
          "Let's move on...\n")
    
# to make answer more prominent from the next question 
print('^' * 100)

######### Input 4 #########

# Question 4 is about introducing the cuisine from teammate's home country
# this is not a true or false question, the user choice will return a cuisine
# introduction based on his/her choice.

ans_4 = input(prompt=f"""
Well! I don't know about you but we are getting hungry here.\n
How about we order some food?\n
1.{team_members[0][19]}
2.{team_members[1][19]}
3.{team_members[2][19]}
4.{team_members[3][19]}
5.{team_members[4][19]}\n
Choose a meal by number:
---Don't be greedy, just choose one---
<Press Enter to Continue> """)

# page break
print('-' * 100)

######### Result 4 #########

# the user can only choose one of them and we will have a brief introduction
# about that cuisine

# use if statement to check if the user choose from the given choices
if ans_4 == '1' or ans_4 == '2' or ans_4 == '3' or ans_4 == '4' or ans_4 == '5':
    
    #convert ans_2 string into integer
    ans_4 = int(ans_4)

    # inner statement to check which teammate that the random question belong to
    if ans_4 == team_members[ans_4-1][0]:
      print(f"\nNice choice {user_name}! This cuisine is from our teammate"
               f" {team_members[ans_4-1][2]}'s hometown.\n\n"
               f'"{team_members[ans_4-1][20]}"\n')
    else:
        print(f"\nDamn! Seems like the kitchen is closed. Let's check some "
               "other days.\n")
else:
    print("\nOuch! Seems like you are either greedy or order "
          "the wrong food...\n")
    
# to make answer more prominent from the next question 
print('^' * 100)

######### Input 5 #########

# Question 5 ask users if they could guess which one of the random
# generated cartoon character match of our teammate, we also put a trick
# by giving a hint about a wrong character and see if they fall for it

# generate random number for question 5
random_ques_5 = random.randint(0,4)

# ask user to input based on random generated cartoon character which match one
# of our teammate
ans_5 = input(prompt=f"""
Its time to talk about some fun stuff here! The cartoon characters...Yeah!!!\n
Which cartoon character that represent our teammate {team_members[random_ques_5][1]}?\n
1.{team_members[0][18]}
2.{team_members[1][18]}
3.{team_members[2][18]}
4.{team_members[3][18]}
5.{team_members[4][18]}
6.Power Ranger\n
Choose one of them:
---Shh!!! i think its poxxr raxgxr...---
<Press Enter to Continue> """)

# page break
print('-' * 100)

######### Result 5 #########

# if users got this right, we praise them. We suggested a wrong information and see they
# they take the bait. 

# use if statement to check if the user choose from the given choices
if ans_5 == '1' or ans_5 == '2' or ans_5 == '3' or ans_5 == '4' or \
   ans_5 == '5' or ans_5 == '6':
    
    #convert ans_2 string into integer
    ans_5 = int(ans_5)
    
    # inner statement to check which teammate that the random question belong to
    # condition ==6 is a tricky question which try to trick the user
    # which the actual answer is not in the answer list. So this condition
    # is handle exceptoinally, since 6 is higher than 5 so we place 6 first
    # to make sure all the if statement loop throught
    if ans_5 == 6:
        #true_false is to print correct or incorrect banner
        print(f"{true_false[1]}")
        print(f"\nHahahahahahah! We are sorry {user_name}. We are just fooling "
               "you around...\n"
               "We only got 5 characters and Power Ranger is not one of them.")
    elif ans_5 == team_members[random_ques_5][0]:
        #true_false is to print correct or incorrect banner
        print(f"{true_false[0]}")
        print(f"\nStop watching so much cartoon {user_name}! Go practice your "
               "python or prepare Fisher's article notesssss.\n\nYour answer "
               "is correct though.\n")
    else:
        #true_false is to print correct or incorrect banner
        print(f"{true_false[1]}")
        print(f"\nIncorrect! Obviously you are spending too much time on your "
               "article notes.\n Stop doing that go watch some cartoon "
               f"{user_name}\n")
else:
    print(f"\nOuch! Stop being so creative {user_name}, we only got 5 "
           "characters...\n")

# to make answer more prominent from the next question 
print('^' * 100)
    
######### Input 6 #########

# Question 6 ask user with a random location and see which one of the teammate
# want to travel to that destination

# generate random number for question 6
random_ques_6 = random.randint(0,4)

# ask user input based on the random generated dynamic question.
ans_6 = input(prompt=f"""
It's time to send one of our teammate to a small vacation.\n
Where do you think that our teammate {team_members[random_ques_6][2]} would like to travel?\n
1.{team_members[0][-3]}
2.{team_members[1][-3]}
3.{team_members[2][-3]}
4.{team_members[3][-3]}
5.{team_members[4][-3]}\n
Choose one of the location:
<Press Enter to Continue> """)

# page break
print('-' * 100)

######### Result 6 #########

# If the user got it right, we kind of mess with our teammate that it is dinner next door
# if the user is wrong, we ask user to pay for the trip for the wrong location

# use if statement to check if the user choose from the given choices
if ans_6 == '1' or ans_6 == '2' or ans_6 == '3' or ans_6 == '4' or ans_6 == '5':
    
    #convert ans_2 string into integer
    ans_6 = int(ans_6)
    
    # inner statement to check which teammate that the random question belong to
    if ans_6 == team_members[random_ques_6][1]:
        print(f"{true_false[0]}")
        print(f"\nGood job {user_name}! Thanks to you, we have been able to "
              f"send our teammate to\n the {team_members[random_ques_6][-3]}'s"
              f" restaurant the next block.\nWe are broke at least that's the"
              f" best we could do.")
    else:
        print(f"{true_false[1]}")
        print(f"\nThank god that you got it wrong, we are broke by the way.\n"
              f"Sorry {team_members[random_ques_6][1]}! No vacation for you.")
else:
    print(f"\nOuch! If you want to send {team_members[random_ques_6][1]} to "
          f"{team_members[random_ques_6][-3]}, "
          f"we are fine as long as you are paying...:P\n")

# to make answer more prominent from the next question 
print('^' * 100)
    
######### input 7 #########

# Question 7 ask user a crazy idea and see who does it belong to from our team.
# if the user get it right, we praise the user. If not ,... goodluck user.

# generate random number for question 7
random_ques_7 = random.randint(0,4)

ans_7 = input(prompt=f"""
Crazy people crazy minds.\n
Take a wild guess who is this person "{team_members[random_ques_7][-7]}"?\n
1.{team_members[0][2]}
2.{team_members[1][2]}
3.{team_members[2][2]}
4.{team_members[3][2]}
5.{team_members[4][2]}\n
Choose a number:
<Press Enter to Continue> """)

# page break
print('-' * 100)

######### Result 7 #########

# Users who get it we praise them, if users is wrong we kind of mess with them.

# use if statement to check if the user choose from the given choices
if ans_7 == '1' or ans_7 == '2' or ans_7 == '3' or ans_7 == '4' or ans_7 == '5':
    
    #convert ans_2 string into integer
    ans_7 = int(ans_7)
    
    # inner statement to check which teammate that the random question belong to
    if ans_7 == team_members[random_ques_7][0]:
        print(f"{true_false[0]}")
        print(f"\nWalalala.... {user_name}! Correcto. You know who you are "
              f"dealing with. We are crazy ya?")
    else:
        print(f"{true_false[1]}")
        print(f"\nWrong! we already knew that your imagination isn't as "
               "rich as us...")
else:
    print(f"\nBoom! Wrong input or your keyboard is broken...goodluck..."
           "hahahaha\n")

# to make answer more prominent from the next question 
print('^' * 100)

######### Input 8 #########

# Question 8 ask if the user want to see any celecrity,
# fun thing is we put two of our teammate in the list which
# is a fan of the other.

ans_8 = input(prompt=f"""
Let's introduce you a few celebrities.\n
Which celebrity that you want to get an autograph from?\n
1.{team_members[0][-2]}
2.{team_members[1][-2]}
3.{team_members[2][-2]}
4.{team_members[3][-2]}
5.{team_members[4][-2]}\n
Choose a number:
---Don't be so picky, come on---
<Press Enter to Continue> """)

# page break
print('-' * 100)

######### Result 8 #########

# Answer 8 reply the celebrity which the user are interest, which one of our
# teammate is also a fun, so it would suggest the user to go see the
# celebrity with our teammate.

# use if statement to check if the user choose from the given choices
if ans_8 == '1' or ans_8 == '2' or ans_8 == '3' or ans_8 == '4' or ans_8 == '5':
    
    #convert ans_2 string into integer
    ans_8 = int(ans_8)
    
    # inner statement to check which teammate that the random question belong to
    if ans_8 == team_members[ans_8 - 1][0]:
        print(f"\nInteresting...! Well {team_members[ans_8 - 1][2]} is also "
               "one of his fans.\n"
               "Why don't you guys go get an autograph together.")
    else:
        print(f"\nSeems like the celebrity doesn't wanna meet you...")
else:
    print(f"\nTold you so, don't be so picky!\n")

# to make answer more prominent from the next question 
print('^' * 100)

######### Input 9 #########

# Question 9 ask which type of animal that user want to be
# if the user choose one of them, we suggest the user to
# join one of our teammate which match the criteria

# asked user to input a choice from the list
ans_9 = input(prompt=f"""
Let's explore the nature now...\n
If you were an animal which one would you be?\n
1.{team_members[0][-1]}
2.{team_members[1][-1]}
3.{team_members[2][-1]}
4.{team_members[3][-1]}
5.{team_members[4][-1]}\n
Choose a number:

           ---Don't worry, its just a game.---
---We won't use our magic to turn into an actual ones---
<Press Enter to Continue> """)

# page break
print('-' * 100)

######### Result 9 #########

# Answer 9 reply the matching teammate and the animal type

# use if statement to check if the user choose from the given choices
if ans_9 == '1' or ans_9 == '2' or ans_9 == '3' or ans_9 == '4' or ans_9 == '5':
    
    #convert ans_2 string into integer
    ans_9 = int(ans_9)
    
    # inner statement to check which teammate that the random question belong to
    if ans_9 == team_members[ans_9 - 1][0]:
        print(f"\nWoch!!! You could join {team_members[ans_9 - 1][2]} the next"
               " life.\n"
               f"{team_members[ans_9 - 1][3]} want to be a"
               f" {team_members[ans_9 - 1][-1]} too.")
    else:
        print(f"\nOh! we lost our magic sticks. Sorry, can't turn you into"
              f" {team_members[ans_9 - 1][-1]}...")
else:
    print(f"\nYou should talk to your fingers, they are saying otherwise!\n")
    
# to make answer more prominent from the next question 
print('^' * 100)

######### Input 10 #########

# Question 10 check if users remember the teammate names by answering
# past few questions. If they answer any part of the name right,
# the result will display a picture which represent the teammate
# and the detail information of that particular teammate.

ans_10 = input(prompt=f"""
We believe that now you more or less got to know our teammates.
Enter the teammate that you want to know more about.

Name:
---Full name or nick name---
---First, middle or last names are also acceptable---
<Press Enter to Continue> """)

# page break
print('-' * 100)

######### Result 10 #########

# Answer 10 shows users the team mate represent picture and profile

# use isdigit() function to check if the user enter a number instead of 
# team member name
if ans_10.isdigit() == True:
  print(f"Sorry {user_name}. Numbers are not our teammate names. Goodbye!")

# if the user alphabet then the code will continue to match names
else:
    
  # use if statement to check if the user choose from the given choices
  # team member names' are converted into string for a better index 
  # manipulation purpose

  # user could not only enter full name or nick name, they could also enter
  # first, middle or last name
  if ans_10.lower() == team_members[0][1].lower() or \
    ans_10.lower() == team_members[0][2].lower() or \
    ans_10.lower() == 'htet' or \
    ans_10.lower() == 'aung' or \
    ans_10.lower() == 'kyaw':
          ans_10 = 1
          
  elif ans_10.lower() == team_members[1][1].lower() or \
      ans_10.lower() == team_members[1][2].lower() or \
      ans_10.lower() == 'kabore':
          ans_10 = 2
          
  elif ans_10.lower() == team_members[2][1].lower() or \
      ans_10.lower() == team_members[2][2].lower() or \
      ans_10.lower() == 'lynda' or \
      ans_10.lower() == 'villarreal':
          ans_10 = 3
          
  elif ans_10.lower() == team_members[3][1].lower() or \
      ans_10.lower() == team_members[3][2].lower() or \
      ans_10.lower() == 'tangina' or \
      ans_10.lower() == 'parvez':
          ans_10 = 4
          
  elif ans_10.lower() == team_members[4][1].lower() or \
      ans_10.lower() == team_members[4][2].lower() or \
      ans_10.lower() == 'udhayaa' or \
      ans_10.lower() == 'tamilvanan':
          ans_10 = 5
  else:
      print(f"Sorry {user_name}, you don't remember our names.\n"
            "We don't want to make friend with you. Goodbye!")
      # since user profile index is only 5 index and anything over 5 could cause
      # out of range error. So assign 6 to avoid the bug which cause by 
      # case comparison
      ans_10 = 6
        
  # match the user choice from one of our 5 team member
  # use an if statement plus range function to match conditions
  if ans_10 in range(1,6):
    
    # convert index into a variable for more readible template
    member = team_members[ans_10 - 1]

    # print dynamic team mate template as per user input
    # We try not to use [-1] negative index because keep updating our
    # list and it would lead us to index error.
    
    # print a picture which represent our teammate outlook by ASCII code
    print(f"{profile_pic[ans_10 - 1]}")
      
    # teammate profile template
    print(f'\nGreat! you chose our "{member[14]}" teammate {member[1]}.'
            f" {member[4]} friends called {member[5]} {member[2]}.\n"
            f"{member[3]} is from a beautiful country called {member[6]}."
            f" Which is located in {member[7]}.\n"
            f"{member[2]} speaks {member[8]}.\n"
            f"{member[4]} undergraduate degree was {member[9]}.\n"
            f"{member[3]} has background as {member[10]}.\n\n"
            f"{member[2]} is currently persuing a master in Business Analytics "
            f"at Hult International Business School.\n"
            f"{member[3]} is interested in {member[11]}.\n"
            f"{member[2]} probably will look for an analytics career at "
            f"{member[13]} after graduation.\n"
            f"{member[2]} spends time enjoying {member[4].lower()} hobbies. "
            f"If you like {member[12]},\n"
            f"drop {member[5]} an email at {member[15]}. {member[3]} "
            f"would be more than happy to connnect with you.")

# to make answer more prominent
print('^' * 100)
# Out:
#  .----------------.  .----------------.  .----------------.  .----------------.   .----------------.
# | .--------------. || .--------------. || .--------------. || .--------------. | | .--------------. |
# | |  _________   | || |  _________   | || |      __      | || | ____    ____ | | | |    _____     | |
# | | |  _   _  |  | || | |_   ___  |  | || |     /  \     | || ||_   \  /   _|| | | |   / ___ `.   | |
# | | |_/ | | \_|  | || |   | |_  \_|  | || |    / /\ \    | || |  |   \/   |  | | | |  |_/___) |   | |
# | |     | |      | || |   |  _|  _   | || |   / ____ \   | || |  | |\  /| |  | | | |   .'____.'   | |
# | |    _| |_     | || |  _| |___/ |  | || | _/ /    \ \_ | || | _| |_\/_| |_ | | | |  / /____     | |
# | |   |_____|    | || | |_________|  | || ||____|  |____|| || ||_____||_____|| | | |  |_______|   | |
# | |              | || |              | || |              | || |              | | | |              | |
# ...
